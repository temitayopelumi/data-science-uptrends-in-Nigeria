# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('survey_schema.csv')

# %%
data.head()
# Out:
#   2019 Kaggle Machine Learning and Data Science Survey  \
# 0                                          Question:
# 1                                  # of Respondents:
# 2  Who was excluded? (0 = not excluded; 1 = exclu...
# 3    If What is your age (# years)? 0-17 Is Selected
# 4  If Select the title most similar to your curre...
#
#                             Q1  \
# 0  What is your age (# years)?
# 1                        19717
# 2                            0
# 3                            0
# 4                            0
#
#                                                  Q10  \
# 0  What is your current yearly compensation (appr...
# 1                                              12497
# 2                                                  0
# 3                                                  1
# 4                                                  1
#
#                                                  Q11  \
# 0  Approximately how much money have you spent on...
# ...

# %%
Mcr2019= pd.read_csv('multiple_choice_responses.csv')
# Out:
# C:\Users\TEMI\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (0,3,7,19,34,47,49,50,51,52,53,54,68,81,94,96,109,115,130,139,147,154,167,180,193,206,219,232,245) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Mcr2017=pd.read_csv('multipleChoiceResponses.csv',  encoding='latin-1')
# Out:
# C:\Users\TEMI\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (31,83,86,87,98,99,109,116,123,124,127,129,130,164) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Mcr2018=pd.read_csv('archive (1)/multipleChoiceResponses.csv',  encoding='latin-1')
# Out:
# C:\Users\TEMI\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (0,2,8,10,21,23,24,25,26,27,28,44,56,64,83,85,87,107,109,123,125,150,157,172,174,194,210,218,219,223,246,249,262,264,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,304,306,325,326,329,341,368,371,384,385,389,390,391,393,394) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Mcr2020 = pd.read_csv('kaggle_survey_2020_responses.csv')

# %%
Nigeria2017=Mcr2017[Mcr2017['Country']=='Nigeria']

# %%
Nigeria2018=Mcr2018[Mcr2018['Q3']=='Nigeria']

# %%
Nigeria2019=Mcr2019[Mcr2019['Q3']=='Nigeria']

# %%
Nigeria2020=Mcr2020[Mcr2020['Q3']=='Nigeria']

# %%
Nigeria2017.head()
# Out:
#      GenderSelect  Country   Age  \
# 365          Male  Nigeria  22.0
# 386          Male  Nigeria  42.0
# 708        Female  Nigeria  21.0
# 1199         Male  Nigeria  31.0
# 1358         Male  Nigeria  37.0
#
#                                        EmploymentStatus StudentStatus  \
# 365                                  Employed part-time           NaN
# 386   Independent contractor, freelancer, or self-em...           NaN
# 708              Not employed, and not looking for work           Yes
# 1199                                 Employed full-time           NaN
# 1358                                 Employed full-time           NaN
#
#                                     LearningDataScience CodeWriter  \
# 365                                                 NaN         No
# 386                                                 NaN         No
# 708   Yes, but data science is a small part of what ...        NaN
# 1199                                                NaN        Yes
# ...

# %%
Nigeria2018.head()
# Out:
#      Time from Start to Finish (seconds)      Q1 Q1_OTHER_TEXT     Q2  \
# 18                                  1388    Male            -1  25-29
# 22                                  2458  Female            -1  25-29
# 970                                 3584    Male            -1  25-29
# 1316                                3640    Male            -1  25-29
# 1336                                 821    Male            -1  22-24
#
#            Q3                   Q4  \
# 18    Nigeria  Professional degree
# 22    Nigeria  Bachelorâs degree
# 970   Nigeria  Bachelorâs degree
# 1316  Nigeria  Bachelorâs degree
# 1336  Nigeria  Bachelorâs degree
#
#                                                      Q5                 Q6  \
# 18    Medical or life sciences (biology, chemistry, ...              Other
# 22    Medical or life sciences (biology, chemistry, ...            Student
# 970       Computer science (software engineering, etc.)              Other
# ...

# %%
Nigeria2020.head()
# Out:
#     Time from Start to Finish (seconds)     Q1     Q2       Q3  \
# 63                                  954  35-39    Man  Nigeria
# 100                                 118  18-21  Woman  Nigeria
# 129                               97987  18-21    Man  Nigeria
# 138                              127893  35-39    Man  Nigeria
# 143                                 768  18-21    Man  Nigeria
#
#                          Q4                 Q5                         Q6  \
# 63          Doctoral degree            Student                  1-2 years
# 100         Master’s degree            Student  I have never written code
# 129       Bachelor’s degree            Student                  3-5 years
# 138       Bachelor’s degree  Software Engineer                10-20 years
# 143  I prefer not to answer     Data Scientist                  < 1 years
#
#     Q7_Part_1 Q7_Part_2 Q7_Part_3  ...        Q35_B_Part_2 Q35_B_Part_3  \
# ...

# %%
Nigeria2019.head()
# Out:
#     Time from Start to Finish (seconds)     Q1      Q2 Q2_OTHER_TEXT       Q3  \
# 48                                  648  25-29    Male            -1  Nigeria
# 162                                 519  30-34    Male            -1  Nigeria
# 214                                 868  18-21  Female            -1  Nigeria
# 239                                1627  18-21  Female            -1  Nigeria
# 265                                 398  18-21    Male            -1  Nigeria
#
#                     Q4                  Q5 Q5_OTHER_TEXT  \
# 48     Master’s degree        Data Analyst            -1
# 162  Bachelor’s degree  Research Scientist            -1
# 214  Bachelor’s degree             Student            -1
# 239  Bachelor’s degree      Data Scientist            -1
# 265    Master’s degree        Not employed            -1
#
#                        Q6   Q7  ... Q34_Part_4 Q34_Part_5 Q34_Part_6  \
# 48       50-249 employees  5-9  ...        NaN        NaN        NaN
# ...

# %%
Mcr2019['Q12_Part_2']
# Out:
# 0        Who/what are your favorite media sources that ...
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8              Hacker News (https://news.ycombinator.com/)
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14             Hacker News (https://news.ycombinator.com/)
# 15                                                     NaN
# ...

# %%
def getIndexes(dfObj, value): 
      
    # Empty list 
    listOfPos = [] 
      
    # isin() method will return a dataframe with  
    # boolean values, True at the positions     
    # where element exists 
    result = dfObj.isin([value]) 
      
    # any() method will return  
    # a boolean series 
    seriesObj = result.any() 
  
    # Get list of column names where  
    # element exists 
    columnNames = list(seriesObj[seriesObj == True].index) 
     
    # Iterate over the list of columns and 
    # extract the row index where element exists 
    for col in columnNames: 
        rows = list(result[col][result[col] == True].index) 
  
        for row in rows: 
            listOfPos.append((row, col)) 
              
    # This list contains a list tuples with  
    # the index of element in the dataframe 
    return listOfPos

# %%
Nigeria2019['Q12_Part_1'].astype(str, inplace=True)
# Out:
# 48                                      nan
# 162                                     nan
# 214                                     nan
# 239      Twitter (data science influencers)
# 265      Twitter (data science influencers)
# 325                                     nan
# 642      Twitter (data science influencers)
# 713                                     nan
# 730      Twitter (data science influencers)
# 997      Twitter (data science influencers)
# 1025                                    nan
# 1046                                    nan
# 1065     Twitter (data science influencers)
# 1145                                    nan
# 1228     Twitter (data science influencers)
# 1302                                    nan
# 1335                                    nan
# 1413     Twitter (data science influencers)
# 1446     Twitter (data science influencers)
# 1625                                    nan
# 1648                                    nan
# ...

# %%
list1= Nigeria2019['Q12_Part_1']
for i in list1:
    if i == 'Twitter (data science influencers)':
        position=list1.index(i)
        Nigeria2019['Favourite_data_science_media_source'][position] = 'Twitter'

# if Nigeria2019['Q12_Part_1'] != np.nan:
#     Nigeria2019['Favourite_data_science_media_source'] = Nigeria2019['Q12_Part_1']
# elif Nigeria2019['Q12_Part_2'] != np.nan:
#     Nigeria2019['Favourite_data_science_media_source'] = Nigeria2019['Q12_Part_2']
# elif Nigeria2019['Q12_Part_3'] != np.nan:
#     Nigeria2019['Favourite_data_science_media_source'] = Nigeria2019['Q12_Part_3']
# elif Nigeria2019['Q12_Part_4'] != np.nan:
#     Nigeria2019['Favourite_data_science_media_source'] = Nigeria2019['Q12_Part_4']
# elif Nigeria2019['Q12_Part_5'] != np.nan:
#     Nigeria2019['Favourite_data_science_media_source'] = Nigeria2019['Q12_Part_5']
# elif Nigeria2019['Q12_Part_6'] != np.nan:
#     Nigeria2019['Favourite_data_science_media_source'] = Nigeria2019['Q12_Part_6']
# elif Nigeria2019['Q12_Part_7'] != np.nan:
#     Nigeria2019['Favourite_data_science_media_source'] = Nigeria2019['Q12_Part_7']
# elif Nigeria2019['Q12_Part_8'] != np.nan:
#     Nigeria2019['Favourite_data_science_media_source'] = Nigeria2019['Q12_Part_8']
# elif Nigeria2019['Q12_Part_9'] != np.nan:
#     Nigeria2019['Favourite_data_science_media_source'] = Nigeria2019['Q12_Part_9']
# elif Nigeria2019['Q12_Part_10'] != np.nan:
#     Nigeria2019['Favourite_data_science_media_source'] = Nigeria2019['Q12_Part_10']
# elif Nigeria2019['Q12_Part_11'] != np.nan:
#     Nigeria2019['Favourite_data_science_media_source'] = Nigeria2019['Q12_Part_11']
# else:
#     Nigeria2019['Favourite_data_science_media_source'] = Nigeria2019['Q12_OTHER_TEXT']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-5fb008577884> in <module>
#       2 for i in list1:
#       3     if i == 'Twitter (data science influencers)':
# ----> 4         position=list1.index(i)
#       5         Nigeria2019['Favourite_data_science_media_source'][position] = 'Twitter'
#       6
#
# TypeError: 'Int64Index' object is not callable

# %%
Nigeria2019.rename(columns = {'Time from Start to Finish (seconds)':'Time', 'Q1':'Age', 'Q2': 'GENDER', 'Q2_OTHER_TEXT':'Other_gender',
                             'Q3': 'Country', 'Q4':'Type_of_degree', 'Q5':'JOb_Title', 'Q5_OTHER_TEXT':'Other_job_title','Q6':'Size_of_company'
                             'Q7': 'number_data_scientist_in_company','Q8':'Do_your_employer_use_machine_learning_in_their_business',
                             'Q9_Part_1':'What_you_do_at_work1','Q9_Part_2':'What_you_do_at_work2','Q9_Part_3':'What_you_do_at_work3',
                             'Q9_Part_4':'What_you_do_at_work4','Q9_Part_5':'What_you_do_at_work5','Q9_Part_6':'What_you_do_at_work6',
                             'Q9_Part_7':'What_you_do_at_work7','Q9_Part_8':'What_you_do_at_work8','Q9_OTHER_TEXT':'other_things_you_do_at_work',
                             'Q10':'Annual salary', 'Q11': 'Expenses_for_machine_learning_product_at_work', 'Q12_Part_1':'Favourite_data_science_media_sources1',
                             'Q12_Part_2':'Favourite_data_science_media_sources2','Q12_Part_3':'Favourite_data_science_media_sources3',
                             'Q12_Part_4':'Favourite_data_science_media_sources4','Q12_Part_5':'Favourite_data_science_media_sources5',
                             'Q12_Part_6':'Favourite_data_science_media_sources6','Q12_Part_7':'Favourite_data_science_media_sources7',
                             'Q12_Part_8':'Favourite_data_science_media_sources8','Q12_Part_9':'Favourite_data_science_media_sources9',
                             'Q12_Part_10':'Favourite_data_science_media_sources11','Q12_OTHER_TEXT':'Other_Favourite_data_science_media_sources7',
                             }, inplace = False)
