# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Mcr2017=pd.read_csv('multipleChoiceResponses.csv',  encoding='latin-1')
# Out:
# C:\Users\TEMI\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (31,83,86,87,98,99,109,116,123,124,127,129,130,164) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Mcr2018=pd.read_csv('archive (1)/multipleChoiceResponses.csv',  encoding='latin-1')
# Out:
# C:\Users\TEMI\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (0,2,8,10,21,23,24,25,26,27,28,44,56,64,83,85,87,107,109,123,125,150,157,172,174,194,210,218,219,223,246,249,262,264,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,304,306,325,326,329,341,368,371,384,385,389,390,391,393,394) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Mcr2019= pd.read_csv('multiple_choice_responses.csv')
# Out:
# C:\Users\TEMI\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (0,3,7,19,34,47,49,50,51,52,53,54,68,81,94,96,109,115,130,139,147,154,167,180,193,206,219,232,245) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Mcr2020 = pd.read_csv('kaggle_survey_2020_responses.csv')
# Out:
# C:\Users\TEMI\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Nigeria2017 = Mcr2017[Mcr2017['Country']=='Nigeria']
Nigeria2018 = Mcr2018[Mcr2018['Q3']=='Nigeria']
Nigeria2019 = Mcr2019[Mcr2019['Q3']=='Nigeria']
Nigeria2020 = Mcr2020[Mcr2020['Q3']=='Nigeria']
others2017 = Mcr2017[Mcr2017['Country'] != 'Nigeria']
others2018 = Mcr2018[Mcr2018['Q3'] != 'Nigeria']
others2019 = Mcr2019[Mcr2019['Q3'] != 'Nigeria']
others2020 = Mcr2020[Mcr2020['Q3']!='Nigeria']

# %% [markdown]
# Data science usage in Nigeria

# %%
nigeriaCount = [len(Nigeria2017),len(Nigeria2018),len(Nigeria2019),len(Nigeria2020)]
othersCount = [len(others2017),len(others2018),len(others2019),len(others2020)]
countDict = {"Nigeria":nigeriaCount, "Rest of the World": othersCount, "Year": ['2017','2018','2019','2020']}
countDataframe = pd.DataFrame(countDict)

# %%
countDataframe
# Out:
#    Nigeria  Rest of the World  Year
# 0       73              16643  2017
# 1      208              23652  2018
# 2      395              19323  2019
# 3      476              19561  2020

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
countDataframe.plot(x='Year', y='Nigeria', ax=ax1, color='mediumseagreen') # Our Nigerian sample will be plotted with green
countDataframe.plot(x='Year', y='Rest of the World', ax=ax2)
fig.suptitle('Comparing Number of Survey Respondents over the years')

plt.show()

# %%
# age2020 = age2020[age2020['Q1'] != "What is your age (# years)?"] # filtering out bad data
# age2020 = age2020[age2020['Q1'] != "What is your age (# years)?"]
# age2020 = age2020[age2020['Q1'] != "What is your age (# years)?"]
# age2020 = age2020[age2020['Q1'] != "What is your age (# years)?"]

fig,axs  = plt.subplots(4, figsize=(17, 13))
axes = axs.ravel()
axes[0] = Nigeria2017['Age'].value_counts().sort_index().plot(kind='bar', ax = axes[0], color='mediumseagreen')
axes[1] = Nigeria2018['Q2'].value_counts().sort_index().plot(kind='bar', ax = axes[1], color='mediumseagreen')
axes[2] = Nigeria2019['Q1'].value_counts().sort_index().plot(kind='bar', ax = axes[2], color='mediumseagreen')
axes[3] = Nigeria2020['Q1'].value_counts().sort_index().plot(kind='bar', ax = axes[3], color='mediumseagreen')


# setting titles for each plot
axes[0].set_title('Age Distribution (Nigeria)(2017)')
axes[1].set_title('Age Distribution (Nigeria)(2018)')
axes[2].set_title('Age Distribution (Nigeria)(2019)')
axes[3].set_title('Age Distribution (Nigeria)(2020)')
plt.subplots_adjust(hspace=1.5) # add space between plots to avoid squeezed labels 

# annotate
total2020 = Nigeria2020['Q1'].value_counts().sum()
total2019 = Nigeria2019['Q1'].value_counts().sum()
total2018 = Nigeria2018['Q2'].value_counts().sum()
total2017 = Nigeria2017['Age'].value_counts().sum()
for p in axes[0].patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total2017)
    x = p.get_width()
    y = p.get_y() + p.get_height()
    r,c=p.get_xy()
    axes[0].annotate(percentage, (r+x/2, c+y*1.02),  ha='center')
for p in axes[1].patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total2018)
    x = p.get_width()
    y = p.get_y() + p.get_height()
    r,c=p.get_xy()
    axes[1].annotate(percentage, (r+x/2, c+y*1.02),  ha='center')
for p in axes[2].patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total2019)
    x = p.get_width()
    y = p.get_y() + p.get_height()
    r,c=p.get_xy()
    axes[2].annotate(percentage, (r+x/2, c+y*1.02),  ha='center')
for p in axes[3].patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total2020)
    x = p.get_width()
    y = p.get_y() + p.get_height()
    r,c=p.get_xy()
    axes[3].annotate(percentage, (r+x/2, c+y*1.02), ha='center')
    
fig.show()


fig.show()
# Out:
# C:\Users\TEMI\Anaconda3\lib\site-packages\ipykernel_launcher.py:51: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# C:\Users\TEMI\Anaconda3\lib\site-packages\ipykernel_launcher.py:54: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
Nigeria2020 = Nigeria2020[Nigeria2020['Q1'] != "What is your age (# years)?"] # filtering out bad data
Nigeria2019 = Nigeria2019[Nigeria2019['Q1'] != "What is your age (# years)?"]
Nigeria2018 = Nigeria2018[Nigeria2018['Q1'] != "What is your age (# years)?"]
Nigeria2017 = Nigeria2017[Nigeria2017['Age'] != "What is your age (# years)?"]
# Out:
# C:\Users\TEMI\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
fig,axs = plt.subplots(2,2, figsize=(15, 13)) 
axes = axs.ravel()
axes[0] = Nigeria2017['GenderSelect'].value_counts(ascending=True).plot(kind='bar', ax = axes[0],  color='mediumseagreen')
axes[1] = Nigeria2018['Q1'].value_counts(ascending=True).plot(kind='bar', ax = axes[1], color='mediumseagreen')
axes[2] = Nigeria2019['Q2'].value_counts(ascending=True).plot(kind='bar', ax = axes[2], color='mediumseagreen') 
axes[3] = Nigeria2020['Q2'].value_counts(ascending=True).plot(kind='bar', ax = axes[3], color='mediumseagreen')

axes[0].set_title('In 2017')
axes[1].set_title('In 2018')
axes[2].set_title('In 2019')
axes[3].set_title('In 2020')
plt.subplots_adjust(wspace=0.35) # space between plots
fig.suptitle('Gender Distribution in the Survey')

total2020 = Nigeria2020['Q2'].value_counts().sum()
total2019 = Nigeria2019['Q2'].value_counts().sum()
total2018 = Nigeria2018['Q1'].value_counts().sum()
total2017 = Nigeria2017['GenderSelect'].value_counts().sum()

for p in axes[0].patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total2017)
    x = p.get_width()
    y = p.get_y() + p.get_height()
    r,c=p.get_xy()
    axes[0].annotate(percentage, (r+x/2, c+y*1.02),  ha='center')
for p in axes[1].patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total2018)
    x = p.get_width()
    y = p.get_y() + p.get_height()
    r,c=p.get_xy()
    axes[1].annotate(percentage, (r+x/2, c+y*1.02),  ha='center')
for p in axes[2].patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total2019)
    x = p.get_width()
    y = p.get_y() + p.get_height()
    r,c=p.get_xy()
    axes[2].annotate(percentage, (r+x/2, c+y*1.02),  ha='center')
for p in axes[3].patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total2020)
    x = p.get_width()
    y = p.get_y() + p.get_height()
    r,c=p.get_xy()
    axes[3].annotate(percentage, (r+x/2, c+y*1.02), ha='center')
    
fig.show()
# Out:
# C:\Users\TEMI\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
Data_science_usage_years  =   [Nigeria2018['Q10'],Nigeria2019['Q8'],Nigeria2020['Q22'], others2018['Q10'],others2019['Q8'],others2020['Q22']]

# %% [markdown]
# Lets see the usage of data science in Nigeria companies compared to others.

# %%
def clean(i):
    i = i.str.split('(').str.get(0)
    i.dropna(inplace=True)
    return i

# %%
# for year in Data_science_usage_years:
#     clean(year)

# %%
Nigeria2019['Q8'] =  clean(Nigeria2019['Q8'])

# %%
Nigeria2018['Q10'] = clean(Nigeria2018['Q10'])

# %%
Nigeria2020['Q22']  = clean(Nigeria2020['Q22'])

# %%
Nigeria2020['Q22']
# Out:
# 63                                         NaN
# 100                                        NaN
# 129                                        NaN
# 138                                        No
# 143                              I do not know
# 219                                        NaN
# 305                                        NaN
# 450                                        NaN
# 461                                        NaN
# 487               We are exploring ML methods
# 600               We are exploring ML methods
# 664                                        NaN
# 688               We are exploring ML methods
# 713               We are exploring ML methods
# 719                                        NaN
# 782                                        No
# 793                                        NaN
# 797                              I do not know
# 804                                        No
# 867                                        NaN
# ...

# %%
Nigeria2018['Q10']
# Out:
# 18                                              No
# 22                                              No
# 970                                             No
# 1316                                            No
# 1336                                  I do not know
# 1352                                            No
# 1412                                            NaN
# 1664                   We are exploring ML methods
# 1700                   We are exploring ML methods
# 2068                                            NaN
# 2148                   We are exploring ML methods
# 2615                   We are exploring ML methods
# 2617                                            No
# 2954                                            No
# 3058                                  I do not know
# 3233                                            No
# 3478                                            No
# 3792                                            No
# ...

# %%
fig,(ax1,ax2) = plt.subplots(2)

ax1 = Nigeria2020['Q5'].value_counts(ascending=True).plot(kind='barh', ax = ax1, color='mediumseagreen')
ax2 = others2020['Q5'].value_counts(ascending=True).plot(kind='barh', ax = ax2)
ax1.set_title('Occupation (Nigeria)')
ax2.set_title('Occupation (Rest of the World)')
plt.subplots_adjust(wspace=30)
